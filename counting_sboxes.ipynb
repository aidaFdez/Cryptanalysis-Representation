# %%
with open("permutations_sbox_t2.txt", "r") as f:
    line = f.readlines()

# %%
line[0]
# Out:
# '(1, 2, 5, 4, 3, 6, 7, 8): -46.06843143067582\n'

# %%
line[0][:24]
# Out:
# '(1, 2, 5, 4, 3, 6, 7, 8)'

# %%
line[0][26:-1]
# Out:
# '-46.06843143067582'

# %%
print(line[0][:3])
print(line[0][0:6])
print(line[0][0:9])
print(line[0][0:12])
print(line[0][0:15])
print(line[0][0:18])
# Out:
# (1,
# (1, 2,
# (1, 2, 5,
# (1, 2, 5, 4,
# (1, 2, 5, 4, 3,
# (1, 2, 5, 4, 3, 6,

# %%
dic_one = {}
dic_two = {}
dic_three = {}
dic_four = {}
dic_five = {}
dic_six = {}
probs = {}
for l in line:
    one = l[:3]
    two = l[:6]
    three = l[:9]
    four = l[:12]
    five = l[:15]
    six = l[:18]
    prob = l[26:-1]
    if one in dic_one:
        dic_one[one] = dic_one[one]+1
        print
    else:
        print(one)        
        dic_one[one] = 1
    if two in dic_two:
        dic_two[two] += 1
    else:
        dic_two[two] = 1
    if three in dic_three:
        dic_three[three] += 1
    else:
        dic_three[three] = 1
    if four in dic_four:
        dic_four[four] += 1
    else:
        dic_four[four] = 1
    if five in dic_five:
        dic_five[five] += 1
    else:
        dic_five[five] = 1
    if six in dic_six:
        dic_six[six] += 1
    else:
        dic_six[six] = 1
    if prob in probs:
        probs[prob] += 1
    else:
        probs[prob] = 1
# Out:
# (1,
# (2,
# (3,
# (4,
# (5,
# (6,
# (7,
# (8,

# %%
dic_one
# Out:
# {'(1,': 840,
#  '(2,': 816,
#  '(3,': 816,
#  '(4,': 744,
#  '(5,': 864,
#  '(6,': 216,
#  '(7,': 888,
#  '(8,': 936}

# %%
dic_two
# Out:
# {'(1, 2,': 132,
#  '(1, 3,': 132,
#  '(1, 4,': 120,
#  '(1, 5,': 138,
#  '(1, 6,': 30,
#  '(1, 7,': 138,
#  '(1, 8,': 150,
#  '(2, 1,': 132,
#  '(2, 3,': 126,
#  '(2, 4,': 120,
#  '(2, 5,': 132,
#  '(2, 6,': 24,
#  '(2, 7,': 138,
#  '(2, 8,': 144,
#  '(3, 1,': 132,
#  '(3, 2,': 126,
#  '(3, 4,': 120,
#  '(3, 5,': 132,
#  '(3, 6,': 24,
#  '(3, 7,': 138,
#  '(3, 8,': 144,
#  '(4, 1,': 120,
#  '(4, 2,': 120,
#  '(4, 3,': 120,
#  '(4, 5,': 126,
#  '(4, 6,': 6,
#  '(4, 7,': 126,
#  '(4, 8,': 126,
#  '(5, 1,': 138,
#  '(5, 2,': 132,
#  '(5, 3,': 132,
#  '(5, 4,': 126,
#  '(5, 6,': 36,
#  '(5, 7,': 144,
#  '(5, 8,': 156,
#  '(6, 1,': 30,
#  '(6, 2,': 24,
#  '(6, 3,': 24,
#  '(6, 4,': 6,
#  '(6, 5,': 36,
#  '(6, 7,': 42,
#  '(6, 8,': 54,
#  '(7, 1,': 138,
#  '(7, 2,': 138,
#  '(7, 3,': 138,
#  '(7, 4,': 126,
#  '(7, 5,': 144,
#  '(7, 6,': 42,
#  '(7, 8,': 162,
#  '(8, 1,': 150,
#  '(8, 2,': 144,
#  '(8, 3,': 144,
#  '(8, 4,': 126,
#  '(8, 5,': 156,
#  '(8, 6,': 54,
#  '(8, 7,': 162}

# %%
dic_three
# Out:
# {'(1, 2, 5,': 6,
#  '(1, 2, 6,': 120,
#  '(1, 2, 7,': 6,
#  '(1, 3, 5,': 6,
#  '(1, 3, 6,': 120,
#  '(1, 3, 7,': 6,
#  '(1, 4, 6,': 120,
#  '(1, 5, 3,': 6,
#  '(1, 5, 6,': 120,
#  '(1, 5, 7,': 12,
#  '(1, 6, 3,': 6,
#  '(1, 6, 5,': 12,
#  '(1, 6, 7,': 12,
#  '(1, 7, 3,': 6,
#  '(1, 7, 5,': 12,
#  '(1, 7, 6,': 120,
#  '(1, 8, 3,': 6,
#  '(1, 8, 5,': 12,
#  '(1, 8, 6,': 120,
#  '(1, 8, 7,': 12,
#  '(2, 1, 5,': 6,
#  '(2, 1, 6,': 120,
#  '(2, 1, 7,': 6,
#  '(2, 3, 1,': 6,
#  '(2, 3, 6,': 120,
#  '(2, 4, 6,': 120,
#  '(2, 5, 1,': 6,
#  '(2, 5, 6,': 120,
#  '(2, 5, 7,': 6,
#  '(2, 6, 1,': 12,
#  '(2, 6, 5,': 6,
#  '(2, 6, 7,': 6,
#  '(2, 7, 1,': 12,
#  '(2, 7, 5,': 6,
#  '(2, 7, 6,': 120,
#  '(2, 8, 1,': 12,
#  '(2, 8, 5,': 6,
#  '(2, 8, 6,': 120,
#  '(2, 8, 7,': 6,
#  '(3, 1, 5,': 6,
#  '(3, 1, 6,': 120,
#  '(3, 1, 7,': 6,
#  '(3, 2, 1,': 6,
#  '(3, 2, 6,': 120,
#  '(3, 4, 6,': 120,
#  '(3, 5, 1,': 6,
#  '(3, 5, 6,': 120,
#  '(3, 5, 7,': 6,
#  '(3, 6, 1,': 12,
#  '(3, 6, 5,': 6,
# ...

# %%
prev = "0"
count = []
for l in line:
    if '-46.06843143067582' in l:
        if not prev == l[:12]:
            print(l)
            prev = l[:12]
        count.append(l)
print(len(count))
# Out:
# (1, 2, 5, 4, 3, 6, 7, 8): -46.06843143067582
#
# (1, 2, 7, 4, 3, 5, 6, 8): -46.06843143067582
#
# (1, 3, 5, 4, 2, 6, 7, 8): -46.06843143067582
#
# (1, 3, 7, 4, 2, 5, 6, 8): -46.06843143067582
#
# (1, 5, 3, 4, 2, 6, 7, 8): -46.06843143067582
#
# (1, 5, 7, 4, 2, 3, 6, 8): -46.06843143067582
#
# (1, 6, 3, 4, 2, 5, 7, 8): -46.06843143067582
#
# (1, 6, 5, 4, 2, 3, 7, 8): -46.06843143067582
#
# (1, 6, 7, 4, 2, 3, 5, 8): -46.06843143067582
#
# (1, 7, 3, 4, 2, 5, 6, 8): -46.06843143067582
#
# (1, 7, 5, 4, 2, 3, 6, 8): -46.06843143067582
#
# (1, 8, 3, 4, 2, 5, 6, 7): -46.06843143067582
#
# (1, 8, 5, 4, 2, 3, 6, 7): -46.06843143067582
#
# (1, 8, 7, 4, 2, 3, 5, 6): -46.06843143067582
#
# (2, 1, 5, 4, 3, 6, 7, 8): -46.06843143067582
#
# (2, 1, 7, 4, 3, 5, 6, 8): -46.06843143067582
#
# (2, 5, 7, 4, 3, 1, 6, 8): -46.06843143067582
#
# (2, 6, 5, 4, 3, 1, 7, 8): -46.06843143067582
#
# (2, 6, 7, 4, 3, 1, 5, 8): -46.06843143067582
#
# (2, 7, 5, 4, 3, 1, 6, 8): -46.06843143067582
#
# ...

# %%
probs
# Out:
# {'-46.06843143067582': 600,
#  '0': 5040,
#  '-43.155870467654374': 120,
#  '-41.224301898330204': 240,
#  '-47.224301898330204': 120}
